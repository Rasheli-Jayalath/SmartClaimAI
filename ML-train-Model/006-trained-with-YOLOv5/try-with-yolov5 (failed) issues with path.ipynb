# %%
# Step 1: Import the necessary libraries
# !pip install torch
# !pip install torchvision

import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pandas as pd

# %%
# Step 2: Define the data directories and classes

# data_dir = '../dataset'
# train_dir = os.path.join(data_dir, 'training')
# valid_dir = os.path.join(data_dir, 'validation')

# data_dir =  "../dataset"
# train_dir = os.path.join(data_dir,  "data3a",   "training"  )
# valid_dir = os.path.join(data_dir,  "data3a",   "validation"  )

# data1a_dir = '../dataset/data1a'
# data1a_train_dir = os.path.join(data1a_dir, 'training')
# data1a_valid_dir = os.path.join(data1a_dir, 'validation')

# data2a_dir = '../dataset/data2a'
# data2a_train_dir = os.path.join(data2a_dir, 'training')
# data2a_valid_dir = os.path.join(data2a_dir, 'validation')

# data3a_dir = '../dataset/data3a'
# data3a_train_dir = os.path.join(data2a_dir, 'training')
# data3a_valid_dir = os.path.join(data2a_dir, 'validation')

# # Step 2: Define the data directories and classes
# data1a_dir = "../dataset/data1a"
# data1a_train_dir = os.path.join(data1a_dir, "training")
# data1a_valid_dir = os.path.join(data1a_dir, "validation")

# data2a_dir = "../dataset/data2a"
# data2a_train_dir = os.path.join(data2a_dir, "training")
# data2a_valid_dir = os.path.join(data2a_dir, "validation")

# data3a_dir = "../dataset/data3a"
# data3a_train_dir = os.path.join(data2a_dir, "training")
# data3a_valid_dir = os.path.join(data2a_dir, "validation")


# # Define the classes
# classes = ['No Damage', 'Damage']
# damage_classes = ['00-minor', '01-moderate', '02-severe']
# location_classes = ['00-front', '01-rear', '02-side']
# type_classes = ['00-damage', '01-whole']

# %%
# # Step 2: Define the data directories and classes
# data1a_dir = "../dataset/data1a"
# data1a_train_dir = os.path.join(data1a_dir, "training")
# data1a_valid_dir = os.path.join(data1a_dir, "validation")

# data2a_dir = "../dataset/data2a"
# data2a_train_dir = os.path.join(data2a_dir, "training")
# data2a_valid_dir = os.path.join(data2a_dir, "validation")

# data3a_dir = "../dataset/data3a"
# data3a_train_dir = os.path.join(data3a_dir, "training")
# data3a_valid_dir = os.path.join(data3a_dir, "validation")

# # Define the classes
# classes = ['No Damage', 'Damage']
# damage_classes = ['00-minor', '01-moderate', '02-severe']
# location_classes = ['00-front', '01-rear', '02-side']
# type_classes = ['00-damage', '01-whole']

# # Step 3: Define the data transforms
# transform_train = transforms.Compose([
#     transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
#     transforms.RandomRotation(degrees=15),
#     transforms.ColorJitter(),
#     transforms.RandomHorizontalFlip(),
#     transforms.CenterCrop(size=224),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ])

# transform_valid = transforms.Compose([
#     transforms.Resize(size=256),
#     transforms.CenterCrop(size=224),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ])

# # Step 4: Define the data loaders
# train_dir = [train_dir, data1a_train_dir, data2a_train_dir, data3a_train_dir]
# valid_dir = [valid_dir, data1a_valid_dir, data2a_valid_dir, data3a_valid_dir]

# train_datasets = [datasets.ImageFolder(dir_, transform=transform_train) for dir_ in train_dir]
# valid_datasets = [datasets.ImageFolder(dir_, transform=transform_valid) for dir_ in valid_dir]

# from torch.utils.data import ConcatDataset
# train_dataset = ConcatDataset(train_datasets)
# valid_dataset = ConcatDataset(valid_datasets)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10952/840617577.py in <module>
#      40 valid_dir = [valid_dir, data1a_valid_dir, data2a_valid_dir, data3a_valid_dir]
#      41
# ---> 42 train_datasets = [datasets.ImageFolder(dir_, transform=transform_train) for dir_ in train_dir]
#      43 valid_datasets = [datasets.ImageFolder(dir_, transform=transform_valid) for dir_ in valid_dir]
#      44
#
# ~\AppData\Local\Temp/ipykernel_10952/840617577.py in <listcomp>(.0)
#      40 valid_dir = [valid_dir, data1a_valid_dir, data2a_valid_dir, data3a_valid_dir]
#      41
# ---> 42 train_datasets = [datasets.ImageFolder(dir_, transform=transform_train) for dir_ in train_dir]
#      43 valid_datasets = [datasets.ImageFolder(dir_, transform=transform_valid) for dir_ in valid_dir]
#      44
#
# ...

# %%
import torch
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define transforms for training and validation data
transform_train = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

transform_valid = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# Define directories for training and validation data
train_dir = ['..dataset/data1a/training/00-damage', '..dataset/data2a/training/00-front', '..dataset/data3a/training/01-minor']
valid_dir = ['..dataset/data1a/validation/00-damage', '..dataset/data2a/validation/00-front', '..dataset/data3a/validation/01-minor']

# Define datasets for training and validation data
train_datasets = [datasets.ImageFolder(dir_, transform=transform_train) for dir_ in train_dir]
valid_datasets = [datasets.ImageFolder(dir_, transform=transform_valid) for dir_ in valid_dir]

# Combine datasets for training and validation data
train_dataset = torch.utils.data.ConcatDataset(train_datasets)
valid_dataset = torch.utils.data.ConcatDataset(valid_datasets)

# Define dataloaders for training and validation data
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=32, shuffle=False, num_workers=4)

# Print dataset sizes
print(f"Training dataset size: {len(train_dataset)}")
print(f"Validation dataset size: {len(valid_dataset)}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10952/2661745715.py in <module>
#      26
#      27 # Define datasets for training and validation data
# ---> 28 train_datasets = [datasets.ImageFolder(dir_, transform=transform_train) for dir_ in train_dir]
#      29 valid_datasets = [datasets.ImageFolder(dir_, transform=transform_valid) for dir_ in valid_dir]
#      30
#
# ~\AppData\Local\Temp/ipykernel_10952/2661745715.py in <listcomp>(.0)
#      26
#      27 # Define datasets for training and validation data
# ---> 28 train_datasets = [datasets.ImageFolder(dir_, transform=transform_train) for dir_ in train_dir]
#      29 valid_datasets = [datasets.ImageFolder(dir_, transform=transform_valid) for dir_ in valid_dir]
#      30
#
# ...

# %%
import torch
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# Define the data augmentation and normalization transforms for the training data
transform_train = transforms.Compose([
    transforms.RandomResizedCrop(size=224),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(degrees=15),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Define the normalization transforms for the validation data
transform_valid = transforms.Compose([
    transforms.Resize(size=256),
    transforms.CenterCrop(size=224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Define datasets for training and validation data
train_datasets = [datasets.ImageFolder(dir_, transform=transform_train) for dir_ in train_dir]
valid_datasets = [datasets.ImageFolder(dir_, transform=transform_valid) for dir_ in valid_dir]

# Concatenate the training and validation datasets
train_dataset = torch.utils.data.ConcatDataset(train_datasets)
valid_dataset = torch.utils.data.ConcatDataset(valid_datasets)

# Define data loaders for the training and validation datasets
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=64, shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10952/1706903736.py in <module>
#      21
#      22 # Define datasets for training and validation data
# ---> 23 train_datasets = [datasets.ImageFolder(dir_, transform=transform_train) for dir_ in train_dir]
#      24 valid_datasets = [datasets.ImageFolder(dir_, transform=transform_valid) for dir_ in valid_dir]
#      25
#
# ~\AppData\Local\Temp/ipykernel_10952/1706903736.py in <listcomp>(.0)
#      21
#      22 # Define datasets for training and validation data
# ---> 23 train_datasets = [datasets.ImageFolder(dir_, transform=transform_train) for dir_ in train_dir]
#      24 valid_datasets = [datasets.ImageFolder(dir_, transform=transform_valid) for dir_ in valid_dir]
#      25
#
# ...

# %%
import os

train_dir = ['../dataset/data1a/training/00-damage', '../dataset/data1a/training/01-whole']
valid_dir = ['../dataset/data1a/validation/00-damage', '../dataset/data1a/validation/01-whole']

for dir_ in train_dir + valid_dir:
    print(os.path.abspath(dir_))
# Out:
# C:\Users\Rasheli\Pictures\SmartClaimAI\ML-train-Model\dataset\data1a\training\00-damage
# C:\Users\Rasheli\Pictures\SmartClaimAI\ML-train-Model\dataset\data1a\training\01-whole
# C:\Users\Rasheli\Pictures\SmartClaimAI\ML-train-Model\dataset\data1a\validation\00-damage
# C:\Users\Rasheli\Pictures\SmartClaimAI\ML-train-Model\dataset\data1a\validation\01-whole

# %%
#Step 3: Define the data transforms

transform_train = transforms.Compose([
    transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
    transforms.RandomRotation(degrees=15),
    transforms.ColorJitter(),
    transforms.RandomHorizontalFlip(),
    transforms.CenterCrop(size=224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transform_valid = transforms.Compose([
    transforms.Resize(size=256),
    transforms.CenterCrop(size=224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
#Step 4: Define the data loaders
train_dir = [train_dir, data1a_train_dir, data2a_train_dir, data3a_train_dir]
valid_dir = [valid_dir, data1a_valid_dir, data2a_valid_dir, data3a_valid_dir]

train_datasets = [datasets.ImageFolder(dir_, transform=transform_train) for dir_ in train_dir]
valid_datasets = [datasets.ImageFolder(dir_, transform=transform_valid) for dir_ in valid_dir]
from torch.utils.data import ConcatDataset
train_dataset = ConcatDataset(train_datasets)
valid_dataset = ConcatDataset(valid_datasets)

# train_datasets = datasets.ImageFolder(train_dir, transform=transform_train)
# valid_datasets = datasets.ImageFolder(valid_dir, transform=transform_valid)

# train_dir = [train_dir, data1a_train_dir, data2a_train_dir, data3a_train_dir]
# valid_dir = [valid_dir, data1a_valid_dir, data2a_valid_dir, data3a_valid_dir]

# train_datasets = [datasets.ImageFolder(train_dir[i], transform=transform_train) for i in range(len(train_dir))]
# valid_datasets = [datasets.ImageFolder(valid_dir[i], transform=transform_valid) for i in range(len(valid_dir))]
# from torch.utils.data import ConcatDataset
# train_dataset = ConcatDataset(train_datasets)
# valid_dataset = ConcatDataset(valid_datasets)

# train_datasets = datasets.ConcatDataset([    datasets.ImageFolder(train_dir[i], transform=transform_train) for i in range(len(train_dir))
# ])
# valid_datasets = datasets.ConcatDataset([    datasets.ImageFolder(valid_dir[i], transform=transform_valid) for i in range(len(valid_dir))
# ])

# # train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
# # valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False)

# from torch.utils.data import ConcatDataset

# # train_datasets = [    datasets.ImageFolder(train_dir[i], transform=transform_train) for i in range(len(train_dir))
# # ]
# # valid_datasets = [    datasets.ImageFolder(valid_dir[i], transform=transform_valid) for i in range(len(valid_dir))
# # ]

# train_dataset = ConcatDataset(train_datasets)
# valid_dataset = ConcatDataset(valid_datasets)

# train_dir = [
#     train_dir,
#     data1a_train_dir,
#     data2a_train_dir,
#     data3a_train_dir
# ]
# valid_dir = [
#     valid_dir,
#     data1a_valid_dir,
#     data2a_valid_dir,
#     data3a_valid_dir
# ]
# train_datasets = [
#     datasets.ImageFolder(train_dir[i], transform=transform_train) for i in range(len(train_dir))
# ]
# valid_datasets = [
#     datasets.ImageFolder(valid_dir[i], transform=transform_valid) for i in range(len(valid_dir))
# ]

# train_dataset = ConcatDataset(train_datasets)
# valid_dataset = ConcatDataset(valid_datasets)
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=True)
# valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10952/1384903203.py in <module>
#       3 valid_dir = [valid_dir, data1a_valid_dir, data2a_valid_dir, data3a_valid_dir]
#       4
# ----> 5 train_datasets = [datasets.ImageFolder(dir_, transform=transform_train) for dir_ in train_dir]
#       6 valid_datasets = [datasets.ImageFolder(dir_, transform=transform_valid) for dir_ in valid_dir]
#       7 from torch.utils.data import ConcatDataset
#
# ~\AppData\Local\Temp/ipykernel_10952/1384903203.py in <listcomp>(.0)
#       3 valid_dir = [valid_dir, data1a_valid_dir, data2a_valid_dir, data3a_valid_dir]
#       4
# ----> 5 train_datasets = [datasets.ImageFolder(dir_, transform=transform_train) for dir_ in train_dir]
#       6 valid_datasets = [datasets.ImageFolder(dir_, transform=transform_valid) for dir_ in valid_dir]
# ...

# %%
# Step 5: Define the model architecture

# !pip install torch torchvision torchaudio
# !pip install git+https://github.com/ultralytics/yolov5.git

# %%
import torch
import torch.nn as nn

model = torch.hub.load('ultralytics/yolov5', 'custom', path_or_model='yolov5m.pt', verbose=False)

# %%
# Step 6: Define the loss function and optimizer

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
#Step 7: Train the model

def train_model(model, criterion, optimizer, num_epochs=10):
    for epoch in range(num_epochs):
        train_loss = 0.0
        for inputs, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * inputs.size(0)
        
        train_loss = train_loss / len(train_loader.dataset)
        print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch+1, train_loss))

# %%
train_model(model, criterion, optimizer, num_epochs=10)

# %%
# Step 8: Save the trained model

torch.save(model.state_dict(), 'vehicle_damage_detection.pth')

# %%
# Step 9: Test the model

def test_model(model):
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for inputs, labels in val_loader:
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        
        accuracy = correct / total
        print('Accuracy on the validation set: {:.2%}'.format(accuracy))

# %%
test_model(model)

# %%
#Step 10: Make predictions

def predict_image(image_path):
    image = Image.open(image_path)
    image_tensor = transform(image).float()
    image_tensor = image_tensor.unsqueeze_(0)
    input = Variable(image_tensor)
    output = model(input)
    index = output.data.numpy().argmax()
    return index

# %%
index = predict_image('../test_image.jpg')
if index == 0:
    print('The vehicle is not damaged')
else:
    print('The vehicle is damaged')

# %%
def predict_image(image_path):
    image = Image.open(image_path)
    image_tensor = transform(image).float()
    image_tensor = image_tensor.unsqueeze_(0)
    input = Variable(image_tensor)
    output = model(input)
    _, predicted = torch.max(output.data, 1)
    return predicted.item()
